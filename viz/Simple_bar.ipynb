# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np

# %%
plt.rcParams["figure.figsize"] = (12.5,7)
plt.rcParams.update({'font.size': 35})

# %%
a = [9.469668218, 15.45262171, 71.63085089]
tx2 = [0,10,59]
nx = [2.90, 11.5,68]
p_drone = [5.317305835, 8,34.22252989]

## Comment and uncomment as required

mean = [np.mean([nx[0],p_drone[0]]), np.mean([tx2[1],nx[1],p_drone[1]]), np.mean([tx2[2],nx[2],p_drone[2]])]
print(mean)
improvement = [a[0]/mean[0],a[1]/mean[1], kp[2]/mean[2]]
print(improvement)
index = ['A', 'B','C']
colors = ['tab:blue', 'tab:orange', 'tab:red','tab:purple', 'tab:grey']
df = pd.DataFrame({'X': kp,
                   'Y': tx2, 'Z':nx,'Foo': p_drone, 'Mean':mean}, index=index)
ax = df.plot.bar(color=colors, alpha=0.8)
#ax.get_legend().remove()
#ax.grid(linestyle='--', color='grey',linewidth=1,axis='x')
plt.xticks(rotation=0)
#ax.set_xlabel('Low-Obstacle Environment')

ax.set_ylabel('Metric')
plt.savefig('filename.pdf',dpi=300 , bbox_inches='tight')
plt.show()
# Out:
# [4.1086529175, 9.833333333333334, 53.74084329666667]
# [2.304810946104941, 1.5714530552542372, 1.3328940614975981]
